# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('duzce_cleaned_data.csv')

# %%
df
# Out:
#      Building_height  Building_age  Torsional_irregularity  \
# 0              12.00          24.0                       1
# 1              11.20          19.0                       2
# 2              11.20           8.0                       2
# 3              16.20          14.0                       2
# 4              16.20          14.0                       2
# ..               ...           ...                     ...
# 478             8.55          18.0                       2
# 479            11.20           3.0                       1
# 480            11.20           5.0                       2
# 481            11.20           5.0                       2
# 482            14.50           6.0                       1
#
#      Projection_in_plan  Minimum_normalized_lateral_stiffness_index  \
# 0                     2                                    0.091896
# 1                     2                                    0.079054
# 2                     2                                    0.068851
# 3                     2                                    0.043574
# 4                     2                                    0.036941
# ..                  ...                                         ...
# 478                   2                                    0.053323
# 479                   2                                    0.158659
# 480                   2                                    0.198931
# 481                   2                                    0.175697
# 482                   2                                    0.069198
#
#      Minimum_normalized_lateral_strength_index  Overhanging_ratio  \
# 0                                     3.005807           0.114932
# 1                                     2.256757           0.152568
# 2                                     1.717742           0.202016
# 3                                     1.690346           0.071803
# 4                                     1.207469           0.120498
# ..                                         ...                ...
# 478                                   2.306667           0.039771
# 479                                   2.896653           0.075902
# 480                                   2.655852           0.170534
# 481                                   2.605994           0.167368
# 482                                   1.918092           0.244313
#
#      Normalized_redundancy_score  Priority_index       PGA   PGV/PGA  \
# 0                              1        0.013702  1.195908  0.074858
# 1                              2        0.010158  1.195908  0.074858
# 2                              1        0.007218  1.195908  0.074858
# 3                              2        0.005137  1.195908  0.074858
# 4                              1        0.009077  1.195908  0.074858
# ..                           ...             ...       ...       ...
# 478                            3        0.020086  1.195908  0.074858
# 479                            1        0.010472  1.195908  0.074858
# 480                            2        0.009189  1.195908  0.074858
# 481                            2        0.009430  1.195908  0.074858
# 482                            1        0.005573  1.195908  0.074858
#
#      Effective_SaT1 Class
# 0          0.897751     M
# 1          0.916526     M
# 2          0.754786     M
# 3          0.604847     M
# 4          0.604847     M
# ..              ...   ...
# 478        0.868699     M
# 479        0.754786     M
# 480        0.754786     L
# 481        0.754786     L
# 482        0.846129     L
#
# [483 rows x 13 columns]

# %%
df['Class'].replace({'C/R':0, 'L':1, 'M':2, 'N':3, 'S':4}, inplace=True)

# %%
df
# Out:
#      Building_height  Building_age  Torsional_irregularity  \
# 0              12.00          24.0                       1
# 1              11.20          19.0                       2
# 2              11.20           8.0                       2
# 3              16.20          14.0                       2
# 4              16.20          14.0                       2
# ..               ...           ...                     ...
# 478             8.55          18.0                       2
# 479            11.20           3.0                       1
# 480            11.20           5.0                       2
# 481            11.20           5.0                       2
# 482            14.50           6.0                       1
#
#      Projection_in_plan  Minimum_normalized_lateral_stiffness_index  \
# 0                     2                                    0.091896
# 1                     2                                    0.079054
# 2                     2                                    0.068851
# 3                     2                                    0.043574
# 4                     2                                    0.036941
# ..                  ...                                         ...
# 478                   2                                    0.053323
# 479                   2                                    0.158659
# 480                   2                                    0.198931
# 481                   2                                    0.175697
# 482                   2                                    0.069198
#
#      Minimum_normalized_lateral_strength_index  Overhanging_ratio  \
# 0                                     3.005807           0.114932
# 1                                     2.256757           0.152568
# 2                                     1.717742           0.202016
# 3                                     1.690346           0.071803
# 4                                     1.207469           0.120498
# ..                                         ...                ...
# 478                                   2.306667           0.039771
# 479                                   2.896653           0.075902
# 480                                   2.655852           0.170534
# 481                                   2.605994           0.167368
# 482                                   1.918092           0.244313
#
#      Normalized_redundancy_score  Priority_index       PGA   PGV/PGA  \
# 0                              1        0.013702  1.195908  0.074858
# 1                              2        0.010158  1.195908  0.074858
# 2                              1        0.007218  1.195908  0.074858
# 3                              2        0.005137  1.195908  0.074858
# 4                              1        0.009077  1.195908  0.074858
# ..                           ...             ...       ...       ...
# 478                            3        0.020086  1.195908  0.074858
# 479                            1        0.010472  1.195908  0.074858
# 480                            2        0.009189  1.195908  0.074858
# 481                            2        0.009430  1.195908  0.074858
# 482                            1        0.005573  1.195908  0.074858
#
#      Effective_SaT1  Class
# 0          0.897751      2
# 1          0.916526      2
# 2          0.754786      2
# 3          0.604847      2
# 4          0.604847      2
# ..              ...    ...
# 478        0.868699      2
# 479        0.754786      2
# 480        0.754786      1
# 481        0.754786      1
# 482        0.846129      1
#
# [483 rows x 13 columns]

# %%
df.head()
# Out:
#    Building_height  Building_age  Torsional_irregularity  Projection_in_plan  \
# 0             12.0          24.0                       1                   2
# 1             11.2          19.0                       2                   2
# 2             11.2           8.0                       2                   2
# 3             16.2          14.0                       2                   2
# 4             16.2          14.0                       2                   2
#
#    Minimum_normalized_lateral_stiffness_index  \
# 0                                    0.091896
# 1                                    0.079054
# 2                                    0.068851
# 3                                    0.043574
# 4                                    0.036941
#
#    Minimum_normalized_lateral_strength_index  Overhanging_ratio  \
# 0                                   3.005807           0.114932
# 1                                   2.256757           0.152568
# 2                                   1.717742           0.202016
# 3                                   1.690346           0.071803
# 4                                   1.207469           0.120498
#
#    Normalized_redundancy_score  Priority_index       PGA   PGV/PGA  \
# 0                            1        0.013702  1.195908  0.074858
# 1                            2        0.010158  1.195908  0.074858
# 2                            1        0.007218  1.195908  0.074858
# 3                            2        0.005137  1.195908  0.074858
# 4                            1        0.009077  1.195908  0.074858
#
#    Effective_SaT1  Class
# 0        0.897751      2
# 1        0.916526      2
# 2        0.754786      2
# 3        0.604847      2
# 4        0.604847      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Building_height                             483 non-null    float64
#  1   Building_age                                483 non-null    float64
#  2   Torsional_irregularity                      483 non-null    int64
#  3   Projection_in_plan                          483 non-null    int64
#  4   Minimum_normalized_lateral_stiffness_index  483 non-null    float64
#  5   Minimum_normalized_lateral_strength_index   483 non-null    float64
#  6   Overhanging_ratio                           483 non-null    float64
#  7   Normalized_redundancy_score                 483 non-null    int64
#  8   Priority_index                              483 non-null    float64
#  9   PGA                                         483 non-null    float64
#  10  PGV/PGA                                     483 non-null    float64
#  11  Effective_SaT1                              483 non-null    float64
#  12  Class                                       483 non-null    int64
# dtypes: float64(9), int64(4)
# memory usage: 49.2 KB

# %%
sns.histplot(df['Priority_index'], kde=True, bins=15)
# Out:
# <Axes: xlabel='Priority_index', ylabel='Count'>

# %%
sns.histplot(df['Class'], kde=True, bins=15)
# Out:
# <Axes: xlabel='Class', ylabel='Count'>

# %%
sns.displot(df['Priority_index'], kde=True, bins=10)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# using Pearson Correlation

plt.figure(figsize=(20,16))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
sns.pairplot(df)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
cols_to_plot = ['PGA', 'PGV/PGA', 'Priority_index', 'Class']

# %%
sns.pairplot(df[cols_to_plot])
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df[cols_to_plot], diag_kind ='kde')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Adding a regresssiopn line

sns.pairplot(df[cols_to_plot], diag_kind ='kde', kind='reg')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#using plot_kws to change regression line color
sns.pairplot(df[cols_to_plot], diag_kind ='kde', kind='reg', plot_kws={'line_kws':{'color':'red'}})
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Splitting data by category

sns.pairplot(df[cols_to_plot], hue='Class')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.pairplot(df[cols_to_plot], kind='scatter', diag_kind='kde')

# remove upper triangle plots
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from scipy.stats import pearsonr
def reg_coef(x,y,label=None,color=None,**kwargs):
    ax = plt.gca()
    r,p = pearsonr(x,y)
    ax.annotate('r = {:.2f}'.format(r), xy=(0.5,0.5), xycoords='axes fraction', ha='center')
    ax.set_axis_off()

g = sns.PairGrid(df[cols_to_plot])
g.map_diag(sns.distplot)
g.map_lower(sns.regplot)
g.map_upper(reg_coef)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
