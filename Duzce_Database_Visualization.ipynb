# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Cleaned_data.csv')

# %%
df
# Out:
#      Construction_time  Storey_height  Number_of_stories  Floor_area  \
# 0               1975.0           3.00                  4       884.0
# 1               1980.0           2.80                  4       888.0
# 2               1991.0           2.80                  4       992.0
# 3               1985.0           2.70                  6       915.0
# 4               1985.0           2.70                  6       723.0
# ..                 ...            ...                ...         ...
# 477             1981.0           2.85                  3      1050.0
# 478             1996.0           2.80                  4       488.0
# 479             1994.0           2.80                  4       524.0
# 480             1994.0           2.80                  4       456.0
# 481             1993.0           2.90                  5      1310.0
#
#      Plan_irregularity_A1  Plan_irregularity_A2  Plan_irregularity_A3  \
# ...

# %%
df.drop(['storey_number'], axis=1, inplace=True)
df.drop(['Column_area'], axis=1, inplace=True)

# %%
df['Class'].replace({'C/R':0, 'L':1, 'M':2, 'N':3, 'S':4}, inplace=True)

# %%
df
# Out:
#      Construction_time  Storey_height  Number_of_stories  Floor_area  \
# 0               1975.0           3.00                  4       884.0
# 1               1980.0           2.80                  4       888.0
# 2               1991.0           2.80                  4       992.0
# 3               1985.0           2.70                  6       915.0
# 4               1985.0           2.70                  6       723.0
# ..                 ...            ...                ...         ...
# 477             1981.0           2.85                  3      1050.0
# 478             1996.0           2.80                  4       488.0
# 479             1994.0           2.80                  4       524.0
# 480             1994.0           2.80                  4       456.0
# 481             1993.0           2.90                  5      1310.0
#
#      Plan_irregularity_A1  Plan_irregularity_A2  Plan_irregularity_A3  \
# ...

# %%
df.head()
# Out:
#    Construction_time  Storey_height  Number_of_stories  Floor_area  \
# 0             1975.0            3.0                  4       884.0
# 1             1980.0            2.8                  4       888.0
# 2             1991.0            2.8                  4       992.0
# 3             1985.0            2.7                  6       915.0
# 4             1985.0            2.7                  6       723.0
#
#    Plan_irregularity_A1  Plan_irregularity_A2  Plan_irregularity_A3  \
# 0                   1.0                   2.0                   2.0
# 1                   2.0                   2.0                   2.0
# 2                   2.0                   2.0                   2.0
# 3                   2.0                   2.0                   2.0
# 4                   2.0                   2.0                   2.0
#
#    Plan_irregularity_A4  Vertical_irregularity_B1  Vertical_irregularity_B2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Construction_time         482 non-null    float64
#  1   Storey_height             482 non-null    float64
#  2   Number_of_stories         482 non-null    int64
#  3   Floor_area                482 non-null    float64
#  4   Plan_irregularity_A1      482 non-null    float64
#  5   Plan_irregularity_A2      482 non-null    float64
#  6   Plan_irregularity_A3      482 non-null    float64
#  7   Plan_irregularity_A4      482 non-null    float64
#  8   Vertical_irregularity_B1  482 non-null    float64
#  9   Vertical_irregularity_B2  482 non-null    float64
#  10  Vertical_irregularity_B3  482 non-null    float64
#  11  Bays_Number_x             482 non-null    float64
#  12  Bays_Number_y             482 non-null    float64
# ...

# %%
sns.histplot(df['Floor_area'], kde=True, bins=15)
# Out:
# <Axes: xlabel='Floor_area', ylabel='Count'>

# %%
sns.histplot(df['Class'], kde=True, bins=15)
# Out:
# <Axes: xlabel='Class', ylabel='Count'>

# %%
sns.displot(df['Floor_area'], kde=True, bins=10)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# using Pearson Correlation

plt.figure(figsize=(20,16))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
sns.pairplot(df)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
cols_to_plot = ['Number_of_stories', 'Floor_area', 'Storey_height', 'Class']

# %%
sns.pairplot(df[cols_to_plot])
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df[cols_to_plot], diag_kind ='kde')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Adding a regresssiopn line

sns.pairplot(df[cols_to_plot], diag_kind ='kde', kind='reg')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#using plot_kws to change regression line color
sns.pairplot(df[cols_to_plot], diag_kind ='kde', kind='reg', plot_kws={'line_kws':{'color':'red'}})
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Splitting data by category

sns.pairplot(df[cols_to_plot], hue='Class')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.pairplot(df[cols_to_plot], kind='scatter', diag_kind='kde')

# remove upper triangle plots
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from scipy.stats import pearsonr
def reg_coef(x,y,label=None,color=None,**kwargs):
    ax = plt.gca()
    r,p = pearsonr(x,y)
    ax.annotate('r = {:.2f}'.format(r), xy=(0.5,0.5), xycoords='axes fraction', ha='center')
    ax.set_axis_off()

g = sns.PairGrid(df[cols_to_plot])
g.map_diag(sns.distplot)
g.map_lower(sns.regplot)
g.map_upper(reg_coef)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
